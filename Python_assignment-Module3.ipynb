# %%
# version 7.0
import random
from matplotlib import pyplot as plt
from itertools import combinations
def bleh():
    sales = list()
    price = [0, 4.25, 2.50, 2.00, 1.25, 1.50, 1.75, 3.75]
    for i in range(1, 31):
        per_day_sales = 0
        no_of_customers = random.randrange(20, 51)
        for day in range(no_of_customers):
                    no_of_items = random.randrange(3, 8)
                    bill = 0
                    order = list()
                    combos_applicable = list()
                    for i in range(1, no_of_items+1):
                        order.append(random.randrange(1, 8))
#                     print(order)
                    order.sort()
                    combo_3s = list(set(combinations(order, 3)))
                    combo_4s = list(set(combinations(order, 4)))
                    all_combos = [(1, 2, 6, 7), (1, 2, 5, 7), (1, 2, 4, 7), (1, 3, 6), (1, 3, 5), (1, 3, 4)]
                    obtained_combos = list()
                    for i in combo_3s:
                        obtained_combos.append(i)
                    for i in combo_4s:
                        obtained_combos.append(i)
                    for i in obtained_combos:
                        if i in all_combos:
                            combos_applicable.append(i)
                    if all_combos[0] in obtained_combos and len(order) > 4:
                        bill += 7.9625
                        for i in all_combos[0]:
                            if i in order:
                                order.remove(i)
                        order.sort()
                        if order in all_combos:
                            ind = all_combos.index(order)
                            if(all_combos[ind] == (1, 3, 6)):
                                bill += 6.4
                            elif(all_combos[ind] == (1, 3, 5)):
                                bill += 6.2
                            elif(all_combos[ind] == (1, 3, 4)):
                                bill += 6
                        for i in order:
                            bill += price[i]
                    elif all_combos[1] in obtained_combos and len(order) > 4:
                        bill += 7.8
                        for i in all_combos[1]:
                            if i in order:
                                order.remove(i)
                        order.sort()
                        if order in all_combos:
                            ind = all_combos.index(order)
                            if(all_combos[ind] == (1, 3, 6)):
                                bill += 6.4
                            elif(all_combos[ind] == (1, 3, 5)):
                                bill += 6.2
                            elif(all_combos[ind] == (1, 3, 4)):
                                bill += 6
                        for i in order:
                            bill += price[i]
                    elif all_combos[2] in obtained_combos and len(order) > 4:
                        bill += 7.6375
                        for i in all_combos[2]:
                            if i in order:
                                order.remove(i)
                        order.sort()
                        if order in all_combos:
                            ind = all_combos.index(order)
                            if(all_combos[ind] == (1, 3, 6)):
                                bill += 6.4
                            elif(all_combos[ind] == (1, 3, 5)):
                                bill += 6.2
                            elif(all_combos[ind] == (1, 3, 4)):
                                bill += 6
                        for i in order:
                            bill += price[i]
                    elif all_combos[3] in obtained_combos:
                        bill += 6.4
                        for i in all_combos[3]:
                            if i in order:
                                order.remove(i)
                        order.sort()
                        c1 = list(set(combinations(order, 3)))
                        if all_combos[4] in c1:
                            bill += 6.2
                            for i in all_combos[4]:
                                order.remove(i)
                        elif all_combos[5] in c1:
                            bill += 6
                            for i in all_combos[5]:
                                order.remove(i)
                        for i in order:
                            bill += price[i]
                    elif all_combos[4] in obtained_combos:
                        bill += 6.2
                        for i in all_combos[4]:
                            if i in order:
                                order.remove(i)
                        order.sort()
                        c1 = list(set(combinations(order, 3)))
                        if all_combos[5] in c1:
                            bill += 6
                            for i in all_combos[5]:
                                order.remove(i)
                        for i in order:
                            bill += price[i]
                    elif all_combos[5] in obtained_combos:
                        bill += 6
                        for i in all_combos[5]:
                            order.remove(i)
                        order.sort()
                        c1 = list(set(combinations(order, 3)))
                        if all_combos[5] in c1:
                            bill += 6
                            for i in all_combos[5]:
                                order.remove(i)
                        for i in order:
                            bill += price[i]
                    else:
                        for i in order:
                            bill += price[i]
                    bill = 1.18 * bill
                    per_day_sales += bill
        sales.append(per_day_sales)
    month = list()
    for i in range(30):
        month.append(i)
    plt.plot(month, sales)
    plt.show()

# %%
bleh()
